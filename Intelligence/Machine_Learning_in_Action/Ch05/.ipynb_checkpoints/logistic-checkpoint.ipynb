# %%
import logRegres 
reload(logRegres)
dataMatIn, classLabels = logRegres.loadDataSet()
weights = logRegres.gradAscent(dataMatIn,classLabels)
# Out:
# (100L, 3L)
# (3L, 1L)
# 0
# [[ 0.9999997 ]
#  [ 0.98616889]
#  [ 0.99887232]
#  [ 0.99892083]
#  [ 0.99999619]
#  [ 0.99979122]
#  [ 0.99999945]
#  [ 0.99553342]
#  [ 0.99998516]
#  [ 0.99998882]
#  [ 0.99984482]
#  [ 0.99999982]
#  [ 0.99524519]
#  [ 0.99975551]
#  [ 0.99793879]
#  [ 0.97128332]
#  [ 0.99919801]
#  [ 0.97477903]
#  [ 0.77681757]
#  [ 0.99957748]
#  [ 0.9980066 ]
#  [ 0.22252829]
#  [ 0.99999498]
#  [ 0.26394949]
#  [ 0.8246228 ]
#  [ 0.99999261]
#  [ 0.99991432]
#  [ 0.01392443]
#  [ 0.99215449]
#  [ 0.99999407]
#  [ 0.99007735]
#  [ 0.99994736]
#  [ 0.999999  ]
#  [ 0.05986936]
#  [ 0.99921454]
#  [ 0.99997998]
#  [ 0.99997966]
#  [ 0.99982544]
#  [ 0.99999104]
#  [ 0.99998525]
#  [ 0.97919678]
#  [ 0.99971059]
#  [ 0.99997751]
#  [ 0.93705909]
#  [ 0.9890627 ]
#  [ 0.99996675]
#  [ 0.1359093 ]
#  [ 0.99921684]
#  [ 0.99999079]
#  [ 0.99999622]
#  [ 0.99995015]
#  [ 0.99998279]
#  [ 0.99982675]
#  [ 0.99999982]
#  [ 0.9994663 ]
#  [ 0.99964232]
#  [ 0.9999885 ]
# ...

# %%
weights
# Out:
# matrix([[ 4.12414349],
#         [ 0.48007329],
#         [-0.6168482 ]])

# %%
logRegres.plotBestFit(weights.getA())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-ee7ae16f44ce> in <module>()
# ----> 1 logRegres.plotBestFit(weights.getA())
#
# C:\Users\huangzhen\Google Drive\Books\Machine_Learning_In_Action\Ch05\logRegres.py in plotBestFit(weights)
#      39         weights = weights + alpha * dataMatrix.transpose()* error #matrix mult
#      40     return weights
# ---> 41
#      42 def plotBestFit(weights):
#      43     import matplotlib.pyplot as plt
#
# C:\Program Files\Anaconda2\lib\site-packages\matplotlib\pyplot.py in <module>()
#      34 from matplotlib import docstring
#      35 from matplotlib.backend_bases import FigureCanvasBase
# ---> 36 from matplotlib.figure import Figure, figaspect
#      37 from matplotlib.gridspec import GridSpec
#      38 from matplotlib.image import imread as _imread
#
# ...

# %%
logRegres.multiTest()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-e456e0a05100> in <module>()
# ----> 1 logRegres.multiTt()
#
# AttributeError: 'module' object has no attribute 'multiTt'
